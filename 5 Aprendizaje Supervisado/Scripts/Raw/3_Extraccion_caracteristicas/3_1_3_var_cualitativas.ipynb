# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

print(np.unique(nivel_estudios, return_counts=True) )
# Out:
# (array(['Bachillerato', 'Doctorado', 'Grado', 'Master', 'Secundaria'],
#       dtype='<U12'), array([172,  21, 145,  52, 110], dtype=int64))

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Master' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Master' 'Master' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Grado' 'Master' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Grado' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Doctorado' 'Doctorado' 'Bachillerato' 'Doctorado' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Doctorado' 'Grado' 'Doctorado' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Master' 'Grado' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.grid()
plt.bar(estudios, frecuencia , color='grey', ) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'grey', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.1f%%')
plt.title('Diagrama de sectores')
plt.show()
