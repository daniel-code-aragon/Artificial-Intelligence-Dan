# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os

# %%
direct_path = os.getcwd()
file_path = os.path.join(direct_path,'valenbisi-disponibilitat-valenbisi-dsiponibilidad.csv')

# %%
valen_df= pd.read_csv(file_path , delimiter=';')

# %%
valen_df.head()
# Out:
#       gid                       name  number_  \
# 0  901618    38_AVDA. PERIS Y VALERO       38
# 1  901645   065_AVDA. DEL PUERTO III       65
# 2  901655            075_CAMPOAMOR I       75
# 3  901654  074_PLAZA SAN FELIPE NERI       74
# 4  901653      073_JERONIMO MONSORIU       73
#
#                                    address open  available  free  total  \
# 0               Peris y Valero - Cabo Jubi    T          0    20     20
# 1       Av. Puerto - Doctor Manuel Candela    T          2    17     19
# 2          República Argentina - Campoamor    T          2    23     25
# 3  Plaza San Felipe Neri (Mercado Algirós)    T          7    13     20
# 4            Jerónimo Monsoriu - Industria    T         12     7     20
#
#   ticket           updated_at                                globalid  \
# 0      F  19/05/2023 09:49:50  {76A36858-7C93-4958-8A8B-22280B953817}
# 1      T  19/05/2023 09:49:50  {77CDBBB8-91C3-4EA5-A8CE-4DC7580DC298}
# ...

# %%
valen_df.describe(include= 'all')
# Out:
#                   gid                     name     number_  \
# count      276.000000                      276  276.000000
# unique            NaN                      276         NaN
# top               NaN  38_AVDA. PERIS Y VALERO         NaN
# freq              NaN                        1         NaN
# mean    901718.500000                      NaN  138.500000
# std         79.818544                      NaN   79.818544
# min     901581.000000                      NaN    1.000000
# 25%     901649.750000                      NaN   69.750000
# 50%     901718.500000                      NaN  138.500000
# 75%     901787.250000                      NaN  207.250000
# max     901856.000000                      NaN  276.000000
#
#                            address open   available        free       total  \
# count                          276  276  276.000000  276.000000  276.000000
# unique                         276    2         NaN         NaN         NaN
# ...

# %%
valen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gid               276 non-null    int64
#  1   name              276 non-null    object
#  2   number_           276 non-null    int64
#  3   address           276 non-null    object
#  4   open              276 non-null    object
#  5   available         276 non-null    int64
#  6   free              276 non-null    int64
#  7   total             276 non-null    int64
#  8   ticket            276 non-null    object
#  9   updated_at        276 non-null    object
#  10  globalid          276 non-null    object
#  11  created_user      0 non-null      float64
#  12  created_date      0 non-null      float64
#  13  last_edited_user  0 non-null      float64
#  14  last_edited_date  0 non-null      float64
#  15  geo_shape         276 non-null    object
# ...

# %%
def drop_cols(data,cols):    
    data= data.drop(columns=cols )
    return data

# %%
columnas=['created_user','created_date','last_edited_user','last_edited_date']

valen_df= drop_cols(valen_df, columnas)

valen_df.head()
# Out:
#       gid                       name  number_  \
# 0  901618    38_AVDA. PERIS Y VALERO       38
# 1  901645   065_AVDA. DEL PUERTO III       65
# 2  901655            075_CAMPOAMOR I       75
# 3  901654  074_PLAZA SAN FELIPE NERI       74
# 4  901653      073_JERONIMO MONSORIU       73
#
#                                    address open  available  free  total  \
# 0               Peris y Valero - Cabo Jubi    T          0    20     20
# 1       Av. Puerto - Doctor Manuel Candela    T          2    17     19
# 2          República Argentina - Campoamor    T          2    23     25
# 3  Plaza San Felipe Neri (Mercado Algirós)    T          7    13     20
# 4            Jerónimo Monsoriu - Industria    T         12     7     20
#
#   ticket           updated_at                                globalid  \
# 0      F  19/05/2023 09:49:50  {76A36858-7C93-4958-8A8B-22280B953817}
# 1      T  19/05/2023 09:49:50  {77CDBBB8-91C3-4EA5-A8CE-4DC7580DC298}
# ...

# %%
estaciones= valen_df['updated_at'].unique()
print(sorted(estaciones))
# Out:
# ['19/05/2023 09:49:50']
